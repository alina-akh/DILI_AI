# %%
import requests
import asyncio
import aiohttp
import pandas as pd
import time

# %%
# testset
# compound_names = [
#     'Mercaptopurine',
#     'Acetaminophen',
#     'Azathioprine',
#     'Chlorpheniramine maleate',
#     'Clofibrate',
# ]

SEMAPHORE_LIMIT = 5
RATE_LIMIT_DELAY = 0.21  # limitation of pubchem server

async def fetch_cid(session, name, semaphore):
    async with semaphore:
        url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{name.replace(' ', '%20')}/cids/TXT"
        try:
            async with session.get(url, timeout=aiohttp.ClientTimeout(total=10)) as response:
                if response.status == 200:
                    text = await response.text()
                    cids = text.strip().split()
                    cid = cids[0] if cids else None
                    await asyncio.sleep(RATE_LIMIT_DELAY) 
                    return name, cid
                else:
                    print(f" 1 {name} → HTTP error {response.status}")
                    await asyncio.sleep(RATE_LIMIT_DELAY)
                    return name, None
        except Exception as e:
            print(f" 0 {name} → URL error: {e}")
            await asyncio.sleep(RATE_LIMIT_DELAY)
            return name, None

async def get_cids_async(names):
    semaphore = asyncio.Semaphore(SEMAPHORE_LIMIT)
    async with aiohttp.ClientSession() as session:
        tasks = [fetch_cid(session, name, semaphore) for name in names]
        results = await asyncio.gather(*tasks)
        return dict(results)

def get_smiles_batch(cids, cid_to_smiles):
    if not cids:
        print("cids is empty")
        return cid_to_smiles
    cid_str = ','.join(cids)
    url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/{cid_str}/property/CanonicalSMILES/JSON"
    try:
        res = requests.get(url, timeout=15)
        if res.status_code == 200:
            data = res.json()
            # CID → SMILES
            for prop in data['PropertyTable']['Properties']:
                cid_to_smiles[str(prop['CID'])] = prop.get('ConnectivitySMILES', '')
            return cid_to_smiles
        else:
            print(f"Batch SMILES request failed: HTTP {res.status_code}")
            return {}
    except Exception as e:
        print(f"Error in batch SMILES request: {e}")
        return {}

# test
# name_to_cid = await get_cids_async(compound_names)
# valid_cids = [cid for cid in name_to_cid.values() if cid is not None]
# cid_to_smiles = get_smiles_batch(valid_cids)

# %%
dili_rank = pd.read_excel("DILI_rank.xlsx")
dili_rank.rename(columns={"Drug Induced Liver Injury Rank (DILIrank) Dataset Ver 2.0 | FDA": "LTKBID",
                          "Unnamed: 1": "CompoundName",
                          "Unnamed: 2": "SeverityClass",
                          "Unnamed: 3": "LabelSection",
                          "Unnamed: 4": "vDILI-Concern",
                          "Unnamed: 5": "Comment"}, inplace=True)
dili_rank = dili_rank.drop(0)

# %%
compounds_name = dili_rank["CompoundName"].tolist()
name_to_cid = await get_cids_async(compounds_name)
valid_cids = [cid for cid in name_to_cid.values() if cid is not None]
# Out:
#  1 CompoundName → HTTP error 404
#  1 Abatacept → HTTP error 404
#  1 Abciximab → HTTP error 404
#  1 Acetylcholine chloride → HTTP error 503
#  1 Adalimumab → HTTP error 404
#  1 Adenosine → HTTP error 503
#  1 Alaproclate → HTTP error 503
#  1 Alemtuzumab → HTTP error 404
#  1 Aldesleukin → HTTP error 503
#  1 Alglucosidase alfa → HTTP error 404
#  1 Almotriptan malate → HTTP error 503
#  1 Alosetron hydrochloride → HTTP error 503
#  1 Alteplase → HTTP error 404
#  1 Ambenonium chloride → HTTP error 503
#  1 Aminosalicylic acid  → HTTP error 404
#  1 Amiodarone hydrochloride → HTTP error 503
#  1 Anakinra → HTTP error 404
#  1 Anidulafungin → HTTP error 503
#  1 Antithymocyte globulin → HTTP error 404
#  1 Argatroban → HTTP error 503
#  1 Argipressin → HTTP error 503
#  1 Asparaginase → HTTP error 404
#  1 Atenolol → HTTP error 503
#  1 Avanafil → HTTP error 503
#  1 Avapritinib → HTTP error 503
#  1 Basiliximab → HTTP error 404
#  1 Belumosudil mesylate → HTTP error 503
#  1 Benzylpenicilloyl polylysine → HTTP error 404
#  1 Betaine → HTTP error 503
#  1 Bevacizumab → HTTP error 404
#  1 Bivalirudin → HTTP error 503
#  1 Botulinum toxin type a → HTTP error 404
#  1 Botulinum toxin type b → HTTP error 404
#  1 Bumetanide → HTTP error 503
#  1 Bupropion hydrochloride → HTTP error 503
#  1 Canakinumab → HTTP error 404
#  1 Cefazolin sodium → HTTP error 503
#  1 Cefdinir → HTTP error 503
#  1 Cefditoren pivoxil → HTTP error 503
#  1 Cenobamate → HTTP error 503
#  1 Cephradine → HTTP error 503
#  1 Certolizumab pegol → HTTP error 503
#  1 Ceritinib → HTTP error 503
#  1 Cetuximab → HTTP error 404
#  1 Chlorthalidone → HTTP error 503
#  1 Choriogonadotropin alfa → HTTP error 404
#  1 Clomiphene citrate → HTTP error 503
#  1 Clomipramine hydrochloride → HTTP error 503
#  1 Clonidine hydrochloride → HTTP error 503
#  1 Codeine sulfate → HTTP error 503
#  1 Colesevelam hydrochloride → HTTP error 404
#  1 Cyclophosphamide → HTTP error 503
#  1 Cycloserine → HTTP error 503
#  1 Cyclosporine → HTTP error 503
#  1 Cytarabine → HTTP error 503
#  1 Dalbavancin hydrochloride → HTTP error 404
#  1 Dapsone → HTTP error 503
#  1 Daptomycin → HTTP error 503
#  1 Danazol → HTTP error 503
#  1 Darbepoetin alfa → HTTP error 404
#  1 Dasiglucagon hydrochloride → HTTP error 404
#  1 Delafloxacin meglumine → HTTP error 503
#  1 Denileukin diftitox → HTTP error 404
#  1 Dermatan → HTTP error 404
#  1 Dextromethorphan polistirex → HTTP error 503
#  1 Diatrizoate sodium → HTTP error 503
#  1 Difelikefalin acetate → HTTP error 503
#  1 Dimethyl fumarate → HTTP error 503
#  1 Diphenhydramine hydrochloride → HTTP error 503
#  1 Droxicam → HTTP error 503
#  1 Droxidopa → HTTP error 503
#  1 Eculizumab → HTTP error 404
#  1 Dyphylline → HTTP error 503
#  1 Edaravone → HTTP error 503
#  1 Eprosartan mesylate → HTTP error 503
#  1 Erythropoietin → HTTP error 503
#  1 Estramustine phosphate sodium → HTTP error 503
#  1 Estrogens, conjugated → HTTP error 503
#  1 Estazolam → HTTP error 503
#  1 Eteplirsen → HTTP error 404
#  1 Etanercept → HTTP error 404
#  1 Exenatide synthetic → HTTP error 404
#  1 Famciclovir → HTTP error 503
#  1 Ferumoxides → HTTP error 404
#  1 Ferumoxsil → HTTP error 404
#  1 Filgrastim → HTTP error 404
#  1 Flibanserin → HTTP error 503
#  1 Florbetaben f-18 → HTTP error 503
#  1 Fluconazole → HTTP error 503
#  1 Flurbiprofen sodium → HTTP error 503
#  1 Follitropin alfa/beta → HTTP error 404
#  1 Fondaparinux sodium → HTTP error 503
#  1 Fosfomycin tromethamine → HTTP error 503
#  1 Gadopentetate dimeglumine → HTTP error 503
#  1 Gallium nitrate → HTTP error 503
#  1 Galsulfase → HTTP error 404
#  1 Gemtuzumab ozogamicin → HTTP error 404
#  1 Givosiran sodium → HTTP error 404
#  1 Glycopyrrolate → HTTP error 503
#  1 Golimumab → HTTP error 404
#  1 Golodirsen → HTTP error 503
#  1 Heparin sodium → HTTP error 503
#  1 Hetastarch → HTTP error 404
#  1 Hyaluronidase → HTTP error 404
#  1 Hyaluronidase recombinant human → HTTP error 404
#  1 Ibritumomab tiuxetan → HTTP error 404
#  1 Ibufenac → HTTP error 503
#  1 Idursulfase → HTTP error 404
#  1 Idelalisib → HTTP error 503
#  1 Imatinib mesylate → HTTP error 503
#  1 Imiglucerase → HTTP error 404
#  1 Inclisiran sodium → HTTP error 404
#  1 Infliximab → HTTP error 404
#  1 Interferon alfa-2a, recombinant → HTTP error 404
#  1 Interferon beta-1a → HTTP error 404
#  1 Interferon alfacon-1 → HTTP error 404
#  1 Interferon beta-1b → HTTP error 404
#  1 Interferon gamma-1b → HTTP error 404
#  1 Interferon alfa-2b → HTTP error 503
#  1 Iothalamate meglumine → HTTP error 503
#  1 Ivabradine hydrochloride → HTTP error 503
#  1 Ketamine hydrochloride → HTTP error 503
#  1 Lansoprazole → HTTP error 503
#  1 Lanthanum carbonate → HTTP error 503
#  1 Laronidase → HTTP error 404
#  1 Leflunomide → HTTP error 503
#  1 Lemborexant → HTTP error 503
#  1 Levetiracetam → HTTP error 503
#  1 Levorphanol tartrate → HTTP error 503
#  1 Levothyroxine sodium → HTTP error 503
#  1 Lisinopril → HTTP error 503
#  1 Lofexidine hydrochloride → HTTP error 503
#  1 Lomitapide mesylate → HTTP error 503
#  1 Lumasiran sodium → HTTP error 404
#  1 Lusutrombopag → HTTP error 503
#  1 Maribavir → HTTP error 503
#  1 Mecasermin recombinant → HTTP error 404
#  1 Mefenamic acid → HTTP error 503
#  1 Mefloquine hydrochloride → HTTP error 503
#  1 Methadone hydrochloride → HTTP error 503
#  1 Methamphetamine hydrochloride → HTTP error 503
#  1 Methazolamide → HTTP error 503
#  1 Methysergide maleate → HTTP error 503
#  1 Mexiletine hydrochloride → HTTP error 503
#  1 Micafungin sodium → HTTP error 503
#  1 Milrinone lactate → HTTP error 503
#  1 Morphine sulfate → HTTP error 503
#  1 Moxidectin → HTTP error 503
#  1 Moxisylyte → HTTP error 503
#  1 Muromonab-cd3 → HTTP error 404
#  1 Nadolol → HTTP error 503
#  1 Natalizumab → HTTP error 404
#  1 Nilotinib hydrochloride → HTTP error 503
#  1 Nimesulide → HTTP error 503
#  1 Nusinersen sodium → HTTP error 404
#  1 Ofatumumab → HTTP error 404
#  1 Olmesartan medoxomil → HTTP error 503
#  1 Omalizumab → HTTP error 404
#  1 Oprelvekin → HTTP error 404
#  1 Oritavancin diphosphate → HTTP error 503
#  1 Oxytetracycline → HTTP error 503
#  1 Oxytocin → HTTP error 503
#  1 Pafuraidine → HTTP error 404
#  1 Palivizumab → HTTP error 404
#  1 Palifermin → HTTP error 404
#  1 Pamidronate disodium → HTTP error 503
#  1 Pancrelipase → HTTP error 404
#  1 Panitumumab → HTTP error 404
#  1 Pasireotide diaspartate → HTTP error 503
#  1 Patiromer sorbitex calcium → HTTP error 404
#  1 Pegaspargase → HTTP error 404
#  1 Pegademase bovine → HTTP error 404
#  1 Patisiran sodium → HTTP error 404
#  1 Peginterferon alfa-2a → HTTP error 404
#  1 Peginterferon alfa-2b → HTTP error 404
#  1 Pegcetacoplan → HTTP error 503
#  1 Pegvisomant → HTTP error 503
#  1 Pentagastrin → HTTP error 503
#  1 Pentosan polysulfate sodium → HTTP error 404
#  1 Phentermine resin complex → HTTP error 404
#  1 Pimavanserin tartrate → HTTP error 503
#  1 Pitolisant hydrochloride → HTTP error 503
#  1 Polyethylene glycol 3350 → HTTP error 404
#  1 Polymyxin b sulfate → HTTP error 404
#  1 Polythiazide → HTTP error 404
#  1 Porfimer sodium → HTTP error 404
#  1 Prasugrel hydrochloride → HTTP error 503
#  1 Propafenone hydrochloride → HTTP error 503
#  1 Propantheline bromide → HTTP error 503
#  1 Protamine sulfate → HTTP error 404
#  1 Protirelin → HTTP error 503
#  1 Quinidine gluconate → HTTP error 503
#  1 Radium ra-223 dichloride → HTTP error 404
#  1 Ramipril → HTTP error 503
#  1 Rasburicase → HTTP error 404
#  1 Remifentanil hydrochloride → HTTP error 503
#  1 Remimazolam besylate → HTTP error 503
#  1 Reteplase → HTTP error 404
#  1 Rifampin → HTTP error 503
#  1 Rilonacept → HTTP error 404
#  1 Riociguat → HTTP error 503
#  1 Romiplostim → HTTP error 404
#  1 Rucaparib camsylate → HTTP error 503
#  1 Rufinamide → HTTP error 503
#  1 Sacrosidase → HTTP error 404
#  1 Sargramostim → HTTP error 404
#  1 Secretin synthetic human → HTTP error 404
#  1 Selinexor → HTTP error 503
#  1 Selumetinib sulfate → HTTP error 503
#  1 Semaglutide → HTTP error 503
#  1 Simethicone-cellulose → HTTP error 404
#  1 Sodium polystyrene sulfonate → HTTP error 404
#  1 Somatropin → HTTP error 404
#  1 Sorafenib tosylate → HTTP error 503
#  1 Stiripentol → HTTP error 503
#  1 Streptomycin sulfate → HTTP error 503
#  1 Sucralfate → HTTP error 404
#  1 Tafamidis meglumine → HTTP error 503
#  1 Technetium tc-99m exametazime kit → HTTP error 404
#  1 Temsirolimus → HTTP error 503
#  1 Tenecteplase → HTTP error 404
#  1 Teriparatide acetate → HTTP error 503
#  1 Tetracycline phosphate complex → HTTP error 404
#  1 Tinzaparin sodium → HTTP error 404
#  1 Trastuzumab → HTTP error 404
#  1 Triamterene → HTTP error 503
#  1 Trimetrexate glucuronate → HTTP error 503
#  1 Urofollitropin → HTTP error 503
#  1 Urokinase → HTTP error 503
#  1 Ustekinumab → HTTP error 404
#  1 Vandetanib → HTTP error 503
#  1 Valsartan → HTTP error 503
#  1 Verteporfin → HTTP error 404
#  1 Vismodegib → HTTP error 503
#  1 Voxelotor → HTTP error 503
#  1 Zidovudine → HTTP error 503
#  1 Zimelidine → HTTP error 503

# %%
batch_size = 300
cid_to_smiles = {}
for batch in [valid_cids[i:i + batch_size] for i in range(0, len(valid_cids), batch_size)]:
    cid_to_smiles = get_smiles_batch(batch, cid_to_smiles)

# %%
dili_rank["CID"] = dili_rank["CompoundName"].map(name_to_cid)
dili_rank["SMILES"] = dili_rank["CID"].map(cid_to_smiles)

# %%
dili_rank_clean = dili_rank.dropna(subset=["SMILES"])

# %%
dili_rank_clean
# Out:
#        LTKBID               CompoundName SeverityClass  \
# 1     LT00040           Abacavir sulfate             8
# 2     LT03618              Abaloparatide             0
# 5     LT03619                Abemaciclib             3
# 6     LT02339        Abiraterone acetate             8
# 7     LT03614              Acalabrutinib             4
# ...       ...                        ...           ...
# 1332  LT01017  Ziprasidone hydrochloride             3
# 1333  LT01088            Zoledronic acid             0
# 1334  LT01010               Zolmitriptan             3
# 1335  LT00164          Zolpidem tartrate             7
# 1336  LT00165                 Zonisamide             2
#
#                 LabelSection           vDILI-Concern    Comment       CID  \
# 1     Warnings & precautions      vMOST-DILI-concern  Unchanged    441384
# 2                   No match        vNo-DILI-concern        New  76943386
# 5     Warnings & precautions      vLess-DILI-concern        New  46220502
# 6     Warnings & precautions      vMost-DILI-concern        New   9821849
# 7          Adverse reactions  Ambiguous-DILI-concern        New  71226662
# ...                      ...                     ...        ...       ...
# 1332       Adverse reactions      vLess-DILI-concern  Unchanged    219099
# 1333                No match      vLess-DILI-concern  Unchanged     68740
# 1334       Adverse reactions  Ambiguous-DILI-concern  Unchanged     60857
# 1335       Adverse reactions  Ambiguous-DILI-concern  Unchanged    441338
# 1336       Adverse reactions      vLess-DILI-concern  Unchanged      5734
#
#                                                  SMILES
# 1     C1CC1NC2=C3C(=NC(=N2)N)N(C=N3)C4CC(C=C4)CO.C1C...
# 2     CCC(C)C(C(=O)NC(CCC(=O)N)C(=O)NC(CC(=O)O)C(=O)...
# 5     CCN1CCN(CC1)CC2=CN=C(C=C2)NC3=NC=C(C(=N3)C4=CC...
# 6     CC(=O)OC1CCC2(C3CCC4(C(C3CC=C2C1)CC=C4C5=CN=CC...
# 7     CC#CC(=O)N1CCCC1C2=NC(=C3N2C=CN=C3N)C4=CC=C(C=...
# ...                                                 ...
# 1332  C1CN(CCN1CCC2=C(C=C3C(=C2)CC(=O)N3)Cl)C4=NSC5=...
# 1333               C1=CN(C=N1)CC(O)(P(=O)(O)O)P(=O)(O)O
# 1334             CN(C)CCC1=CNC2=C1C=C(C=C2)CC3COC(=O)N3
# 1335  CC1=CC=C(C=C1)C2=C(N3C=C(C=CC3=N2)C)CC(=O)N(C)...
# 1336                   C1=CC=C2C(=C1)C(=NO2)CS(=O)(=O)N
#
# [1100 rows x 8 columns]

# %%
dili_rank_clean.to_csv('DILI.csv', index=False)
